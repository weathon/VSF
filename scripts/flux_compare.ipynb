# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import sys
sys.path.append("../")
import torch
from src.flux_pipeline import VSFFluxPipeline
import numpy as np
import imageio

pipe = VSFFluxPipeline.from_pretrained("black-forest-labs/FLUX.1-schnell", torch_dtype=torch.bfloat16).to("cuda")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers

# %%
import json
with open("../prompts/test_prompts.json.new", "r") as f:
    prompts = json.load(f)

# %%
os.makedirs("flux_images", exist_ok=True)

# %%
# import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# import sys
# sys.path.append("../")
# import torch
# from src.flux_pipeline import VSFFluxPipeline
# # from src.sd3_pipeline import VSFStableDiffusion3Pipeline
# import numpy as np
# import imageio

# pipe = VSFFluxPipeline.from_pretrained("black-forest-labs/FLUX.1-schnell", torch_dtype=torch.bfloat16).to("cuda")

# %%
# import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# import sys
# sys.path.append("../")
# import torch
# from src.sd3_pipeline import VSFStableDiffusion3Pipeline
# import numpy as np
# import imageio

# pipe = VSFStableDiffusion3Pipeline.from_pretrained("stabilityai/stable-diffusion-3.5-large-turbo", torch_dtype=torch.bfloat16).to("cuda")

# %%
image = pipe(
    prompt="a machine learning scientist working on a laptop in a modern office",
    negative_prompt="it is a male",
    guidance_scale=0.0,
    num_inference_steps=8,
    max_sequence_length=256,
    scale=9,
    offset=0.2,
    generator=torch.Generator("cpu").manual_seed(42)
).images[0]
image
# Out:
# torch.Size([1, 256, 4096]) torch.Size([256, 3]) torch.Size([1, 6, 4096]) torch.Size([6, 3])
#   0%|          | 0/8 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
from diffusers import FluxPipeline
import torch
pipe = FluxPipeline.from_pretrained(
    "black-forest-labs/FLUX.1-schnell",
    torch_dtype=torch.bfloat16,
).to("cuda")
image = pipe(
    prompt="a machine learning scientist working on a laptop in a modern office",
    negative_prompt="male glasses",
    guidance_scale=0.0,
    num_inference_steps=8,
    max_sequence_length=256,
    generator=torch.Generator("cpu").manual_seed(42)
).images[0]
image
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
for i in range(9):
    image = pipe(
        prompts[i]["prompt"],
        negative_prompt=prompts[i]["missing_element"],
        guidance_scale=0.0,
        num_inference_steps=4,
        max_sequence_length=256,
        scale=12,
        offset=0.2,
        generator=torch.Generator("cpu").manual_seed(42)
    ).images[0]
    image.save(f"flux_images/vsf_{i:02d}.png")
# Out:
# torch.Size([1, 256, 4096]) torch.Size([256, 3]) torch.Size([1, 3, 4096]) torch.Size([3, 3])
#   0%|          | 0/4 [00:00<?, ?it/s]
# torch.Size([1, 256, 4096]) torch.Size([256, 3]) torch.Size([1, 2, 4096]) torch.Size([2, 3])
#   0%|          | 0/4 [00:00<?, ?it/s]
# torch.Size([1, 256, 4096]) torch.Size([256, 3]) torch.Size([1, 3, 4096]) torch.Size([3, 3])
#   0%|          | 0/4 [00:00<?, ?it/s]
# torch.Size([1, 256, 4096]) torch.Size([256, 3]) torch.Size([1, 2, 4096]) torch.Size([2, 3])
#   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 12
#       1 for i in range(9):
#       2     image = pipe(
#       3         prompts[i]["prompt"],
#       4         negative_prompt=prompts[i]["missing_element"],
#    (...)
#      10         generator=torch.Generator("cpu").manual_seed(42)
#      11     ).images[0]
# ---> 12     image.save(f"flux_images/vsf_{i:02d}.png")
#
# File ~/miniconda/envs/neg/lib/python3.10/site-packages/PIL/Image.py:2600, in Image.save(self, fp, format, **params)
#    2598         fp = builtins.open(filename, "r+b")
#    2599     else:
# -> 2600         fp = builtins.open(filename, "w+b")
#    2601 else:
#    2602     fp = cast(IO[bytes], fp)
#
# KeyboardInterrupt:

# %%
import torch
from diffusers import FluxPipeline

pipe = FluxPipeline.from_pretrained(
    "black-forest-labs/FLUX.1-schnell",
    torch_dtype=torch.bfloat16,
)

pipe = pipe.to("cuda")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# FluxPipeline {
#   "_class_name": "FluxPipeline",
#   "_diffusers_version": "0.35.0.dev0",
#   "_name_or_path": "black-forest-labs/FLUX.1-schnell",
#   "feature_extractor": [
#     null,
#     null
#   ],
#   "image_encoder": [
#     null,
#     null
#   ],
#   "scheduler": [
#     "diffusers",
#     "FlowMatchEulerDiscreteScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "text_encoder_2": [
#     "transformers",
#     "T5EncoderModel"
#   ],
#   "tokenizer": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "tokenizer_2": [
#     "transformers",
#     "T5TokenizerFast"
#   ],
#   "transformer": [
#     "diffusers",
#     "FluxTransformer2DModel"
#   ],
#   "vae": [
#     "diffusers",
#     "AutoencoderKL"
#   ]
# }

# %%
for i in range(9):
    image = pipe(
        prompts[i]["prompt"],
        guidance_scale=0.0,
        num_inference_steps=4,
        max_sequence_length=256,
        generator=torch.Generator("cpu").manual_seed(42)
    ).images[0]
    image.save(f"flux_images/original_{i:02d}.png")
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
